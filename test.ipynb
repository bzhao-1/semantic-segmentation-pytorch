# %%
from PIL import Image
import numpy as np
import math
from tqdm import tqdm

# %%
a = Image.open("cmky.tiff")
b = Image.open("distance.png")

# %%
a
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=CMYK size=1920x1080>

# %%
from torchvision import transforms
import torch
# normalize = transforms.Normalize(
#             mean=[0.485, 0.456, 0.406, 0.586],
#             std=[0.229, 0.224, 0.225, 0.172])
normalize = transforms.Normalize(
            mean=[0.586],
            std=[0.172])
# img = Image.open("cmky.tiff")
img = Image.open("distance.png")
img = np.float32(np.array(img)) / 255.
img = np.expand_dims(img, axis=2)
img = img.transpose((2, 0, 1))

img = normalize(torch.from_numpy(img.copy()))

for i in range(4):
  print(np.mean(np.array(img)[:,:,i]))
  print(np.std(np.array(img)[:,:,i]))
# Out:
# -0.17142937
# 0.8993695
# -0.17142937
# 0.8993695
# -0.17142937
# 0.8993695
# -0.17142937
# 0.8993695

# %%
np.repeat(np.expand_dims(np.zeros((1920, 1080)), axis = 2), 3, axis=2).shape
# Out:
# (1920, 1080, 3)

# %%
test = np.ones((720, 136, 240))
scalar = np.random.rand(720, 1, 1)
